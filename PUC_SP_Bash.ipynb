# %% [markdown]
# # PUC-SP - Computer Sciene
# ## Bash no Google Colab

# %% [markdown]
# Dicas de Linux terminal:
#
# https://github.com/danielscarvalho/Linux-Commands

# %%
345/67
# Out:
# 5.149253731343284

# %%
# !date
# Out:
# Thu Mar  5 11:42:23 AM UTC 2026

# %%
# !wget https://support.staffbase.com/hc/en-us/article_attachments/360009197071/email.csv
# Out:
# --2026-03-05 11:42:48--  https://support.staffbase.com/hc/en-us/article_attachments/360009197071/email.csv
# Resolving support.staffbase.com (support.staffbase.com)... 216.198.54.11, 216.198.53.11
# Connecting to support.staffbase.com (support.staffbase.com)|216.198.54.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184 [text/csv]
# Saving to: ‘email.csv.1’
#
# email.csv.1         100%[===================>]     184  --.-KB/s    in 0s
#
# 2026-03-05 11:42:48 (63.4 MB/s) - ‘email.csv.1’ saved [184/184]

# %%
# !ls
# Out:
# email.csv  email.csv.1	sample_data

# %%
# !cat email.csv
# Out:
# Login email;Identifier;First name;Last name
# laura@example.com;2070;Laura;Grey
# craig@example.com;4081;Craig;Johnson
# mary@example.com;9346;Mary;Jenkins
# jamie@example.com;5079;Jamie;Smith

# %%
# !uname -a
# Out:
# Linux 13ee7c6300ff 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux

# %% [markdown]
# O comando `history` do Linux/UNIX/Mac mostra os comandos que executamos...
#
# Obtive a lista dos comandos que vimos na aula, os repetidos foram removidos e agora com LLM vou pedir para explicar em uma tabela MD...

# %% [markdown]
# ```bash
#  2001  pwd
#  2002  date
#  2003  tree
#  2004  sudo apt install tree
#  2005  tree
#  2006  man tree
#  2008  htop
#  2009  btop
#  2010  sudo apt install btop
#  2011  btop
#  2012  python
#  2013  clear
#  2014  python
#  2015  clear
#  2016  jshell
#  2017  cd
#  2018  clear
#  2019  cd /opt/jdk-21.0.2/
#  2020  cd bin
#  2021  pwd
#  2022  ./jshell
#  2023  pwd
#  2024  clear
#  2025  pwd
#  2026  cd
#  2027  pwd
#  2028  mkdir puc-teste
#  2029  cd puc-teste
#  2030  ls
#  2031  pwd
#  2032  touch teste.txt
#  2033  ls
#  2034  ls -l
#  2035  clear
#  2036  ls -l
#  2037  vi teste.txt
#  2038  clear
#  2039  ls -l
#  2040  cat teste.txt
#  2041  ls -l
#  2042  chgrp users teste.txt
#  2043  ls -l
#  2044  chmod 700 teste.txt
#  2045  ls -l
#  2046  clear
#  2047  curl http://ip-api.com/json/24.48.0.1
#  2048  curl viacep.com.br/ws/01001000/json/
#  2049  clear
#  2050  ls
#  2051  wget https://support.staffbase.com/hc/en-us/article_attachments/360009197071/email.csv
#  2052  ls
#  2053  ls -l
#  2054  ls
#  2055  clear
#  2056  ls
#  2057  cat email.csv
#  2058  history
#
# ```

# %% [markdown]
# Prompt at X Grok:
#
# I give a lecture on Linux Bash for beginners in computer science, and I show and explain the commands below. Please create a table listing all the commands for reference.

# %% [markdown]
# Here is a clear reference table with all the commands that appeared in your lecture history. I've listed each **unique command** (ignoring repetitions and arguments where they don't change the core command), along with a brief, beginner-friendly explanation suitable for a Computer Science introduction to Bash/Linux.
#
# | Command              | Example from lecture                  | What it does (beginner explanation)                                                                 |
# |----------------------|----------------------------------------|-----------------------------------------------------------------------------------------------------|
# | `pwd`                | `pwd`                                 | Prints the **current working directory** (shows you "where you are" in the file system).           |
# | `date`               | `date`                                | Displays the current date and time.                                                                 |
# | `tree`               | `tree`                                | Shows the directory structure in a nice tree-like visual format (after installation).              |
# | `sudo apt install`   | `sudo apt install tree`<br>`sudo apt install btop` | Installs software/packages using apt (needs admin rights with `sudo`).                              |
# | `man`                | `man tree`                            | Opens the **manual/help page** for a command (press q to exit).                                    |
# | `htop`               | `htop`                                | Interactive process viewer / system monitor (shows CPU, memory, processes — nicer than plain `top`). |
# | `btop`               | `btop`                                | Modern, beautiful system monitor (like htop but with nicer graphs and visuals for CPU/memory/disk/network). |
# | `python`             | `python`                              | Starts the Python interactive interpreter (REPL).                                                  |
# | `clear`              | `clear` (many times)                  | Clears the terminal screen (makes it clean again).                                                  |
# | `jshell`             | `./jshell`                            | Starts the **Java Shell** (REPL for Java — lets you write and test Java code interactively, JDK 9+). |
# | `cd`                 | `cd`, `cd /opt/jdk-21.0.2/`, `cd bin`, `cd puc-teste`, `cd` | **Changes directory** — without arguments goes to your home directory.                             |
# | `mkdir`              | `mkdir puc-teste`                     | Creates a new directory (folder).                                                                   |
# | `ls`                 | `ls`, `ls -l`                         | Lists files and directories in the current folder (`-l` = detailed/long format with permissions, size, date...). |
# | `touch`              | `touch teste.txt`                     | Creates an empty file (or updates timestamp if it already exists).                                 |
# | `vi`                 | `vi teste.txt`                        | Opens the **vi/vim** text editor to edit a file (classic but a bit hard for beginners — :wq to save & quit). |
# | `cat`                | `cat teste.txt`, `cat email.csv`      | Displays the contents of a file on screen (also used to concatenate files).                         |
# | `chgrp`              | `chgrp users teste.txt`               | Changes the **group** ownership of a file.                                                          |
# | `chmod`              | `chmod 700 teste.txt`                 | Changes file **permissions** (700 = owner can read/write/execute, others have no access).          |
# | `curl`               | `curl http://ip-api.com/json/24.48.0.1`<br>`curl viacep.com.br/ws/01001000/json/` | Downloads data from a URL and shows it (great for APIs, testing web requests).                      |
# | `wget`               | `wget https://.../email.csv`          | Downloads a file from the internet and saves it locally.                                            |
# | `history`            | `history`                             | Shows the list of previously executed commands (what you used to generate this list!).             |
#
# This table can be directly used as a handout or slide in your lecture — it keeps only the commands students actually saw, with short explanations focused on beginners.
#
# If you'd like me to add examples, common options, or group them by category (navigation, file manipulation, system info, networking, etc.), just let me know! Good luck with the class! 🐧

# %% [markdown]
# Learning with MIT students:
# https://missing.csail.mit.edu/2026/course-shell/
